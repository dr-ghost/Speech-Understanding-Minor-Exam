# %%
import os
from Q2 import extract_features, load_waveform, zcr_plot, zcr_plot_violin, ste_plot, ste_plot_violin, mfcc_plot, plot_speaker_envolopes
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# Comparizon of speech of:
# PM Shri Narandra Modi vs Mahatma Gandhi

# %%
AUDIO_BASE_PATH = "Speeches of leaders/"

# %%
nm_wav, nm_sr = load_waveform(os.path.join(AUDIO_BASE_PATH, "PM Shri Narendra Modi.mp3"))

# %%
nm_zcr, nm_ste, nm_mfcc = extract_features(nm_wav, nm_sr)

# %%
mg_wav, mg_sr = load_waveform(os.path.join(AUDIO_BASE_PATH, "Mahatma Gandhi.mp3"))

# %%
mg_zcr, mg_ste, mg_mfcc = extract_features(mg_wav, mg_sr)

# %% [markdown]
# #ZCR VISUALIZATIONS

# %%
zcr_plot(nm_zcr, mg_zcr, "Mahatma Gandhi", "Narendra Modi")

# %%
zcr_plot_violin(nm_zcr, mg_zcr, "Mahatma Gandhi", "Narendra Modi")

# %% [markdown]
# #STE VISUALIZATIONS

# %%
ste_plot(nm_ste, mg_ste, "Mahatma Gandhi", "Narandra Modi")

# %%
ste_plot_violin(nm_ste, mg_ste, "Mahatma Gandhi", "Narendra Modi" )

# %% [markdown]
# #MFCC FEATURES VISUALZATION

# %%
mfcc_plot(nm_mfcc, "Naranadra Modi")

# %%
mfcc_plot(mg_mfcc, "Mahatma Gandhi")
